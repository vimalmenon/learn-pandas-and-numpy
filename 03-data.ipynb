# %% [markdown]
# # 03 - Data

# %% [markdown]
# ## Import pandas

# %%
import pandas as pd

# %% [markdown]
# ## Load user csv

# %%
df = pd.read_csv("user.csv")
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  5f10e9D33fC5f2b       Sara   Mcguire  Female
# 1      2  751cD1cbF77e005     Alisha    Hebert    Male
# 2      3  DcEFDB2D2e62bF9  Gwendolyn  Sheppard    Male
# 3      4  C88661E02EEDA9e   Kristine    Mccann  Female
# 4      5  fafF1aBDebaB2a6      Bobby   Pittman  Female
#
#                          Email                  Phone Date of birth  \
# 0           tsharp@example.net     (971)643-6089x9160    1921-08-17
# 1   vincentgarrett@example.net  +1-114-355-1841x78347    1969-06-28
# 2  mercadojonathan@example.com             9017807728    1915-09-25
# 3        lindsay55@example.com  +1-607-333-9911x59088    1978-07-27
# 4    blevinsmorgan@example.com             3739847538    1989-11-17
#
#                            Job Title
# 0              Editor, commissioning
# 1                 Broadcast engineer
# 2                   Industrial buyer
# 3              Multimedia specialist
# ...

# %% [markdown]
# ## Get all Male data

# %%
df_male= df.loc[df["Sex"] == "Male"]
df_male
# Out:
#       Index          User Id First Name Last Name   Sex  \
# 1         2  751cD1cbF77e005     Alisha    Hebert  Male
# 2         3  DcEFDB2D2e62bF9  Gwendolyn  Sheppard  Male
# 6         7  FCdfFf08196f633     Collin   Allison  Male
# 7         8  356279dAa0F7CbD   Nicholas    Branch  Male
# 9        10  f2dceFc00F62542      Pedro   Cordova  Male
# ...     ...              ...        ...       ...   ...
# 9988   9989  bAcc5aC4AEeF920       Lori   Jenkins  Male
# 9989   9990  15FfdA08E12A03D       Bill      Lang  Male
# 9994   9995  7fAFa51c19f5b08      Allen     Stein  Male
# 9995   9996  D66F0e4EdFc35e6       Tina   Sherman  Male
# 9998   9999  34D88Ffc743Ca5B       Emma     Clark  Male
#
#                             Email                  Phone Date of birth  \
# 1      vincentgarrett@example.net  +1-114-355-1841x78347    1969-06-28
# 2     mercadojonathan@example.com             9017807728    1915-09-25
# 6             yvaughn@example.net          (314)591-7413    1979-11-21
# ...

# %% [markdown]
# ## Get all Female data

# %%
df_female = df.loc[df["Sex"] == "Female"]
df_female
# Out:
#       Index          User Id First Name  Last Name     Sex  \
# 0         1  5f10e9D33fC5f2b       Sara    Mcguire  Female
# 3         4  C88661E02EEDA9e   Kristine     Mccann  Female
# 4         5  fafF1aBDebaB2a6      Bobby    Pittman  Female
# 5         6  BdDb6C8Af309202     Calvin     Ramsey  Female
# 8         9  F563CcbFBfEcf5a       Emma   Robinson  Female
# ...     ...              ...        ...        ...     ...
# 9992   9993  d69d6Bc843Fadf3     Marvin  Davenport  Female
# 9993   9994  db16f4EF2FE28FF      Eddie   Clements  Female
# 9996   9997  c753d8B9F5b6054       Earl   Jennings  Female
# 9997   9998  Fb2c7daAdD82dAE      Ellen  Dominguez  Female
# 9999  10000  82D540ce0BE556f    Katrina   Schwartz  Female
#
#                            Email                   Phone Date of birth  \
# 0             tsharp@example.net      (971)643-6089x9160    1921-08-17
# 3          lindsay55@example.com   +1-607-333-9911x59088    1978-07-27
# ...

# %% [markdown]
# ## Change the column Title

# %%
df_new_header = df.rename(columns={"Date of birth": "DOB", "First Name": "FirstName", "Last Name": "LastName", "User Id": "Id"})
df_new_header
# Out:
#       Index               Id  FirstName   LastName     Sex  \
# 0         1  5f10e9D33fC5f2b       Sara    Mcguire  Female
# 1         2  751cD1cbF77e005     Alisha     Hebert    Male
# 2         3  DcEFDB2D2e62bF9  Gwendolyn   Sheppard    Male
# 3         4  C88661E02EEDA9e   Kristine     Mccann  Female
# 4         5  fafF1aBDebaB2a6      Bobby    Pittman  Female
# ...     ...              ...        ...        ...     ...
# 9995   9996  D66F0e4EdFc35e6       Tina    Sherman    Male
# 9996   9997  c753d8B9F5b6054       Earl   Jennings  Female
# 9997   9998  Fb2c7daAdD82dAE      Ellen  Dominguez  Female
# 9998   9999  34D88Ffc743Ca5B       Emma      Clark    Male
# 9999  10000  82D540ce0BE556f    Katrina   Schwartz  Female
#
#                             Email                   Phone         DOB  \
# 0              tsharp@example.net      (971)643-6089x9160  1921-08-17
# 1      vincentgarrett@example.net   +1-114-355-1841x78347  1969-06-28
# ...

# %% [markdown]
# ## Data with specific headers

# %%
df_new_header[["FirstName", "LastName"]]
# Out:
#       FirstName   LastName
# 0          Sara    Mcguire
# 1        Alisha     Hebert
# 2     Gwendolyn   Sheppard
# 3      Kristine     Mccann
# 4         Bobby    Pittman
# ...         ...        ...
# 9995       Tina    Sherman
# 9996       Earl   Jennings
# 9997      Ellen  Dominguez
# 9998       Emma      Clark
# 9999    Katrina   Schwartz
#
# [10000 rows x 2 columns]

# %%
df_new_header[list(df_new_header.columns[1:])]
# Out:
#                    Id  FirstName   LastName     Sex  \
# 0     5f10e9D33fC5f2b       Sara    Mcguire  Female
# 1     751cD1cbF77e005     Alisha     Hebert    Male
# 2     DcEFDB2D2e62bF9  Gwendolyn   Sheppard    Male
# 3     C88661E02EEDA9e   Kristine     Mccann  Female
# 4     fafF1aBDebaB2a6      Bobby    Pittman  Female
# ...               ...        ...        ...     ...
# 9995  D66F0e4EdFc35e6       Tina    Sherman    Male
# 9996  c753d8B9F5b6054       Earl   Jennings  Female
# 9997  Fb2c7daAdD82dAE      Ellen  Dominguez  Female
# 9998  34D88Ffc743Ca5B       Emma      Clark    Male
# 9999  82D540ce0BE556f    Katrina   Schwartz  Female
#
#                             Email                   Phone         DOB  \
# 0              tsharp@example.net      (971)643-6089x9160  1921-08-17
# 1      vincentgarrett@example.net   +1-114-355-1841x78347  1969-06-28
# 2     mercadojonathan@example.com              9017807728  1915-09-25
# ...

# %%
df_new_header.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Index      10000 non-null  int64
#  1   Id         10000 non-null  object
#  2   FirstName  10000 non-null  object
#  3   LastName   10000 non-null  object
#  4   Sex        10000 non-null  object
#  5   Email      10000 non-null  object
#  6   Phone      10000 non-null  object
#  7   DOB        10000 non-null  object
#  8   Job Title  10000 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 703.3+ KB

# %%
df_new_header.describe()
# Out:
#              Index
# count  10000.00000
# mean    5000.50000
# std     2886.89568
# min        1.00000
# 25%     2500.75000
# 50%     5000.50000
# 75%     7500.25000
# max    10000.00000

# %%
df_new_header.dtypes
# Out:
# Index         int64
# Id           object
# FirstName    object
# LastName     object
# Sex          object
# Email        object
# Phone        object
# DOB          object
# Job Title    object
# dtype: object
